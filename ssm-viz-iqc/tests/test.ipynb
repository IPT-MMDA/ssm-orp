# %%
from run_test import run_tests

# %%
run_tests()
# Out:
# /opt/anaconda3/envs/mnist-robust/lib/python3.10/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# test_sdp_runs OK
# test_sdp_runs: OK
# test_pgd_within_epsilon: OK
# test_pgd_runs: OK
# test_sdp_deterministic: OK
# test_sdp_soundness_property: OK
# test_model_forward: OK
# test_sdp_input_shapes: OK

# %% [markdown]
# All tests pass, including the correctness of the PGD attack, determinism, verification of the model's input and output dimensions, and the soundness property of the SDP certificate. This confirms that the implementation of the model, attacks, and SDP verifier are functionally consistent and free of logical errors.
